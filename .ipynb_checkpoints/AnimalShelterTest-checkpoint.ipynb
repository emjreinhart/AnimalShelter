# %%
# Import necessary libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image
from time import sleep
import os
import numpy as np
from sklearn.metrics import r2_score
import sklearn as sk
import math
from amb_sdk.sdk import DarwinSdk

ds = DarwinSdk()
ds.set_url('https://amb-demo-api.sparkcognition.com/v1/')
status, msg = ds.auth_login_user('EM.J.REINHART@GMAIL.COM', 'xeyW2ue46p')

if not status:
    print(msg)

# %%
# Preview dataset
df = pd.read_csv("austin-animal-center-outcomes-1.csv")
df.head(20)

# Upload dataset
# status, dataset = ds.upload_dataset("austin-animal-center-outcomes-1.csv")
# print(status)
# print(dataset)

# if not status:
#     print(dataset)
# Out:
#    Animal ID          Name                DateTime               MonthYear  \
# 0    A771830      *Bradley  12/27/2018 01:25:00 PM  12/27/2018 01:25:00 PM
# 1    A779576        *Rajah  10/01/2018 05:03:00 PM  10/01/2018 05:03:00 PM
# 2    A741715      *Pebbles  01/11/2017 06:17:00 PM  01/11/2017 06:17:00 PM
# 3    A658751         Benji  11/13/2016 01:38:00 PM  11/13/2016 01:38:00 PM
# 4    A721285           NaN  02/24/2016 02:42:00 PM  02/24/2016 02:42:00 PM
# 5    A746650          Rose  04/07/2017 11:58:00 AM  04/07/2017 11:58:00 AM
# 6    A750122  Happy Camper  05/24/2017 06:36:00 PM  05/24/2017 06:36:00 PM
# 7    A756696        Shakti  09/01/2017 11:23:00 AM  09/01/2017 11:23:00 AM
# 8    A784168           NaN  11/14/2018 12:33:00 PM  11/14/2018 12:33:00 PM
# 9    A707443           NaN  07/13/2015 01:50:00 PM  07/13/2015 01:50:00 PM
# 10   A666430          Lucy  11/07/2013 11:47:00 AM  11/07/2013 11:47:00 AM
# 11   A675708       *Johnny  06/03/2014 02:20:00 PM  06/03/2014 02:20:00 PM
# 12   A680386        Monday  06/15/2014 03:50:00 PM  06/15/2014 03:50:00 PM
# 13   A684346           NaN  07/22/2014 04:04:00 PM  07/22/2014 04:04:00 PM
# 14   A754895          Miso  07/30/2017 12:03:00 PM  07/30/2017 12:03:00 PM
# 15   A683115           NaN  07/07/2014 02:04:00 PM  07/07/2014 02:04:00 PM
# 16   A664462        *Edgar  10/07/2013 01:06:00 PM  10/07/2013 01:06:00 PM
# 17   A785671         Toots  12/07/2018 05:36:00 PM  12/07/2018 05:36:00 PM
# 18   A762837           NaN  12/02/2017 04:24:00 PM  12/02/2017 04:24:00 PM
# 19   A713785           NaN  10/19/2015 02:55:00 PM  10/19/2015 02:55:00 PM
#
#    Date of Birth     Outcome Type Outcome Subtype Animal Type  \
# 0     05/10/2017         Adoption          Foster         Dog
# 1     04/18/2018         Adoption             NaN         Cat
# 2     03/07/2016         Adoption             NaN         Cat
# 3     07/14/2011  Return to Owner             NaN         Dog
# 4     02/24/2014       Euthanasia       Suffering       Other
# 5     04/06/2016  Return to Owner             NaN         Dog
# 6     04/08/2017         Transfer         Partner         Dog
# 7     08/24/2014  Return to Owner             NaN         Cat
# 8     03/12/2018         Transfer         Partner         Dog
# 9     06/21/2015         Transfer         Partner         Cat
# 10    11/06/2012         Transfer         Partner         Dog
# 11    03/31/2013         Adoption             NaN         Dog
# 12    06/02/2005         Transfer         Partner         Dog
# 13    07/07/2014         Transfer         Partner         Cat
# 14    06/07/2017         Adoption             NaN         Cat
# 15    01/07/2014       Euthanasia     Rabies Risk       Other
# 16    06/03/2013         Transfer         Partner         Dog
# 17    12/07/2015  Return to Owner             NaN         Cat
# 18    11/28/2016         Transfer         Partner         Dog
# 19    05/29/2015         Transfer         Partner         Dog
#
#    Sex upon Outcome Age upon Outcome  \
# 0     Neutered Male           1 year
# 1     Neutered Male         5 months
# 2     Spayed Female        10 months
# 3     Neutered Male          5 years
# 4           Unknown          2 years
# 5     Intact Female           1 year
# 6       Intact Male          1 month
# 7     Spayed Female          3 years
# 8       Intact Male         8 months
# 9     Intact Female          3 weeks
# 10    Spayed Female           1 year
# 11    Neutered Male           1 year
# 12    Neutered Male          9 years
# 13      Intact Male          2 weeks
# 14      Intact Male          1 month
# 15          Unknown         5 months
# 16      Intact Male         4 months
# 17    Intact Female          3 years
# 18    Neutered Male           1 year
# 19    Neutered Male         4 months
#
#                                                 Breed              Color
# 0                                        Pit Bull Mix         White/Blue
# 1                              Domestic Shorthair Mix        Brown Tabby
# 2                              Domestic Shorthair Mix             Calico
# 3                                  Border Terrier Mix                Tan
# 4                                         Raccoon Mix         Black/Gray
# 5             Labrador Retriever/Jack Russell Terrier             Yellow
# 6                              Labrador Retriever Mix              Black
# 7                              Domestic Shorthair Mix         Blue/White
# 8                        English Springer Spaniel Mix        Black/White
# 9                               Domestic Longhair Mix        Black Smoke
# 10                                         Beagle Mix        White/Brown
# 11                                           Pit Bull         Blue/White
# 12                            Miniature Schnauzer Mix              White
# 13                             Domestic Shorthair Mix       Orange Tabby
# 14                             Domestic Shorthair Mix  Brown Tabby/White
# 15                                            Bat Mix              Brown
# 16                                     Leonberger Mix        Brown/White
# 17                             Domestic Shorthair Mix         Blue Tabby
# 18  Australian Shepherd/Nova Scotia Duck Tolling R...    Chocolate/White
# 19                             Labrador Retriever Mix                Red

# %%
# clean dataset
TRAIN_DATASET = "austin-animal-center-outcomes-1.csv"

status, job_id = ds.clean_data(TRAIN_DATASET, index = "DateTime")

if status:
    ds.wait_for_job(job_id['job_name'])
else:
    print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-10T13:19:22.470007', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['austin-animal-center-outcomes-1.csv'], 'artifact_names': ['ee7977afe7e744029453db1e73f3438e'], 'model_name': None, 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-10T13:19:22.470007', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['austin-animal-center-outcomes-1.csv'], 'artifact_names': ['ee7977afe7e744029453db1e73f3438e'], 'model_name': None, 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-10T13:19:22.470007', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['austin-animal-center-outcomes-1.csv'], 'artifact_names': ['ee7977afe7e744029453db1e73f3438e'], 'model_name': None, 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-10T13:19:22.470007', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['austin-animal-center-outcomes-1.csv'], 'artifact_names': ['ee7977afe7e744029453db1e73f3438e'], 'model_name': None, 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-10T13:19:22.470007', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['austin-animal-center-outcomes-1.csv'], 'artifact_names': ['ee7977afe7e744029453db1e73f3438e'], 'model_name': None, 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-10T13:19:22.470007', 'endtime': '2019-04-10T13:20:27.11014', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['austin-animal-center-outcomes-1.csv'], 'artifact_names': ['ee7977afe7e744029453db1e73f3438e'], 'model_name': None, 'job_error': ''}

# %%
# Create and train model
import datetime
# ts = '{:%Y%m%d%H%M%S}'.format(datetime.datetime.now())
ts = '{:%m%d%Y%H%M%S}'.format(datetime.datetime.now())

target = "Outcome Type"
model = target + "_model0_" + ts

status, job_id = ds.create_model(dataset_names = TRAIN_DATASET, \
                                 model_name =  model, \
                                 max_train_time = '00:05')
if status:
    ds.wait_for_job(job_id['job_name'])
else:
    print(job_id)

# %%
# How many NaN values in Outcome Subtype
# newData = data.fillna("")
# subtype = newData.get('Outcome Subtype')
# empty = 0
# for entry in subtype:
#     if entry== "":
#         empty += 1
# print(empty)

newData = df.fillna("")
subtype = newData.get('Name')
empty = 0
for entry in subtype:
    if entry== "":
        empty += 1
print(empty)
