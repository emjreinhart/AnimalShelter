# %%
import pandas as pd
import numpy as np
import sklearn as sk
import math
import matplotlib.pyplot as plt
from amb_sdk.sdk import DarwinSdk

ds = DarwinSdk()
ds.set_url('https://amb-demo-api.sparkcognition.com/v1/')
status, msg = ds.auth_login_user('EM.J.REINHART@GMAIL.COM', 'xeyW2ue46p')

if not status:
    print(msg)

# %%
# Read the data from csv file
col_names = []
for i in range(12):
    if i == 0:
        col_names.append('Animal ID')
    elif i == 1:
        col_names.append('Name')
    elif i == 2:
        col_names.append('DateTime')
    elif i == 3:
        col_names.append('MonthYear')
    elif i == 4:
        col_names.append('Date of Birth')
    elif i == 5:
        col_names.append('Outcome Type')
    elif i == 6:
        col_names.append('Outcome Subtype')
    elif i == 7:
        col_names.append('Animal Type')
    elif i == 8:
        col_names.append('Sex Upon Outcome')
    elif i == 9:
        col_names.append('Age Upon Outcome')
    elif i == 10:
        col_names.append('Breed')
    elif i == 11:
        col_names.append('Color')

data = pd.read_csv("austin-animal-center-outcomes-1.csv", names = col_names)
print(data.shape)
data.head(20)
# Out:
# (95368, 12)
#     Animal ID          Name                DateTime               MonthYear  \
# 0   Animal ID          Name                DateTime               MonthYear
# 1     A771830      *Bradley  12/27/2018 01:25:00 PM  12/27/2018 01:25:00 PM
# 2     A779576        *Rajah  10/01/2018 05:03:00 PM  10/01/2018 05:03:00 PM
# 3     A741715      *Pebbles  01/11/2017 06:17:00 PM  01/11/2017 06:17:00 PM
# 4     A658751         Benji  11/13/2016 01:38:00 PM  11/13/2016 01:38:00 PM
# 5     A721285           NaN  02/24/2016 02:42:00 PM  02/24/2016 02:42:00 PM
# 6     A746650          Rose  04/07/2017 11:58:00 AM  04/07/2017 11:58:00 AM
# 7     A750122  Happy Camper  05/24/2017 06:36:00 PM  05/24/2017 06:36:00 PM
# 8     A756696        Shakti  09/01/2017 11:23:00 AM  09/01/2017 11:23:00 AM
# 9     A784168           NaN  11/14/2018 12:33:00 PM  11/14/2018 12:33:00 PM
# 10    A707443           NaN  07/13/2015 01:50:00 PM  07/13/2015 01:50:00 PM
# ...

# %%
# How many NaN values in Outcome Subtype
newData = data.fillna("")
subtype = newData.get('Outcome Subtype')
empty = 0
for entry in subtype:
    if entry== "":
        empty += 1
print(empty)
# Out:
# 52087
